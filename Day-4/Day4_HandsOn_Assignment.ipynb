# %% [markdown]
# # Day 4 – Hands-on Assignment
# ## Data Visualisation with Matplotlib & Seaborn
#
# **Level:** Beginner | **Time:** 60–90 minutes
#
# ### Objective
# Analyse a small sales dataset and create visualisations to answer business questions.
#
# ### Submission
# Save this notebook as `Day4_YourName.ipynb`.

# %% [markdown]
# ## Step 1 – Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 2 – Create the Dataset

# %%
data = {
    "Month": ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug"],
    "Sales": [12000,15000,14000,18000,21000,19000,23000,25000],
    "Profit": [2000,2500,2200,3200,4000,3500,4500,5000],
    "Category": ["Phone","Laptop","Phone","Laptop","Tablet","Laptop","Tablet","Laptop"],
    "Region": ["North","South","North","East","West","South","East","North"]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# # Task 1 – Understand the Data
#
# Find:
# - Number of rows and columns
# - First 5 rows
# - Basic statistics
# - Missing values
#
# **Write one observation after running the code.**

# %%
print("Shape:", df.shape)
print("\nFirst 5 rows:")
display(df.head())

print("\nStatistics:")
display(df.describe(numeric_only=True))

print("\nMissing values:")
print(df.isnull().sum())

# %% [markdown]
# ### Your Observation
# Write your answer here.

# %% [markdown]
# # Task 2 – Line Chart
#
# **Question:** How are sales changing month by month?
#
# Requirements:
# - Month → X-axis
# - Sales → Y-axis
# - Title and labels
# - Markers
#
# Hint: `plt.plot()`

# %%
# YOUR CODE

# %% [markdown]
# ### Observation
# Which month has the highest sales?

# %% [markdown]
# # Task 3 – Bar Chart
#
# **Question:** Which month has the highest sales?
#
# Hint: `plt.bar()`

# %%
# YOUR CODE

# %% [markdown]
# # Task 4 – Histogram
#
# **Question:** How are the sales values distributed?
#
# Hint: `plt.hist()`

# %%
# YOUR CODE

# %% [markdown]
# ### Observation
# Are the sales values mostly low, middle or high?

# %% [markdown]
# # Task 5 – Scatter Plot
#
# **Question:** Is there a relationship between Sales and Profit?
#
# - X-axis → Sales
# - Y-axis → Profit
#
# Hint: `plt.scatter()`

# %%
# YOUR CODE

# %% [markdown]
# ### Observation
# Do higher sales generally have higher profit? Explain in one sentence.

# %% [markdown]
# # Task 6 – Seaborn Countplot
#
# **Question:** How many transactions are there in each region?
#
# Hint:
#
# ```python
# sns.countplot(data=df, x="Region")
# ```

# %%
# YOUR CODE

# %% [markdown]
# # Task 7 – Seaborn Barplot
#
# **Question:** Which category has the highest average sales?
#
# Use `sns.barplot()` with:
# - X-axis → Category
# - Y-axis → Sales

# %%
# YOUR CODE

# %% [markdown]
# ### Observation
# Which category has the highest average sales?

# %% [markdown]
# # Task 8 – Boxplot
#
# Create a boxplot for Sales.
#
# **Question:** Can you identify the spread of sales and any possible outliers?
#
# Hint:
#
# ```python
# sns.boxplot(data=df, y="Sales")
# ```

# %%
# YOUR CODE

# %% [markdown]
# # Task 9 – Correlation Heatmap
#
# Calculate the correlation between Sales and Profit and display it as a heatmap.
#
# Hint:
#
# ```python
# corr = df[["Sales", "Profit"]].corr()
# sns.heatmap(corr, annot=True)
# ```

# %%
# YOUR CODE

# %% [markdown]
# ### Observation
# What does the Sales–Profit correlation tell you?

# %% [markdown]
# # Task 10 – Mini Visual Dashboard
#
# Create a **2 × 2** figure containing:
#
# 1. Sales Trend – Line chart
# 2. Sales Distribution – Histogram
# 3. Sales Comparison – Bar chart
# 4. Sales vs Profit – Scatter plot
#
# Hint:
#
# ```python
# fig, ax = plt.subplots(2, 2, figsize=(10, 7))
# ```

# %%
# YOUR CODE

# %% [markdown]
# # Task 11 – Business Insights
#
# Write **5 insights** from your charts.
#
# Example:
# 1. Sales increased from ______ to ______.
# 2. The highest sales occurred in ______.
# 3. The ______ category has the highest average sales.
# 4. Sales and profit show a ______ relationship.
# 5. The region with the most transactions is ______.

# %% [markdown]
# ### Your 5 Insights
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# # Task 12 – Export Data for Power BI
#
# Save the dataset as a CSV.
#
# Power BI Desktop can import this file using **Get Data → Text/CSV**.

# %%
df.to_csv("day4_sales_assignment.csv", index=False)
print("day4_sales_assignment.csv created")

# %% [markdown]
# # Optional Power BI Challenge
#
# Open **Power BI Desktop** and import `day4_sales_assignment.csv`.
#
# Create:
# - 1 Sales KPI card
# - 1 Sales Trend line chart
# - 1 Sales by Category chart
# - 1 Sales by Region chart
# - 1 Region slicer
#
# Save the report as `Day4_YourName.pbix`.

# %% [markdown]
# # Final Submission Checklist
#
# ### Python
# - [ ] Data understanding completed
# - [ ] Line chart
# - [ ] Bar chart
# - [ ] Histogram
# - [ ] Scatter plot
# - [ ] Seaborn countplot
# - [ ] Seaborn barplot
# - [ ] Boxplot
# - [ ] Heatmap
# - [ ] 2 × 2 visual summary
# - [ ] 5 business insights
#
# ### Optional Power BI
# - [ ] CSV imported
# - [ ] KPI card
# - [ ] 3+ visuals
# - [ ] Slicer
# - [ ] `.pbix` saved
#
# ### Submit
# `Day4_YourName.ipynb`

# %% [markdown]
# # Evaluation – 20 Marks
#
# | Area | Marks |
# |---|---:|
# | Data understanding | 2 |
# | Matplotlib charts | 5 |
# | Seaborn charts | 4 |
# | 2 × 2 visual summary | 3 |
# | Business observations | 4 |
# | Code quality | 2 |
# | **Total** | **20** |
#
# ### Key Learning
#
# **Data → Visualisation → Pattern → Insight → Business Decision**
